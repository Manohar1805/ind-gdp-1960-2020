# %% [markdown]
# # importing the required libreries
#
# 1. after importing  read the file using pandas
# 2. cheacked for head and info functions of the data
# 3. cleaned the data for further operations

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv(r"C:\Users\MANOHAR\Downloads\India_GDP_1960-2022.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 India GDP - Historical Data India GDP - Historical Data.1  \
# 0         NaN                        Year            GDP in (Billion) $
# 1         0.0                        2021                        3173.4
# 2         1.0                        2020                       2667.69
# 3         2.0                        2019                       2831.55
# 4         3.0                        2018                       2702.93
#
#   India GDP - Historical Data.2 India GDP - Historical Data.3
# 0          Per Capita in rupees                      Growth %
# 1                        182160                          8.95
# 2                        154640                          -6.6
# 3                        165760                          3.74
# 4                        159840                          6.45

# %% [markdown]
# changed the column names with clear notations

# %%
gdp=df.rename(columns={'India GDP - Histo`rical Data':'Year','India GDP - Historical Data.1':'GDP in (Billion) $','India GDP - Historical Data.2':'Per Capita in rupees','India GDP - Historical Data.3':'Growth per'})

# %%
#gdp.drop('Unnamed:0',axis=1, inplace=True)

# %% [markdown]
# dropped the unnamed column

# %%
gdp.head()
# Out:
#    Year  GDP in (Billion) $  Per Capita in rupees  Growth per
# 1  2021             3173.40                182160        8.95
# 2  2020             2667.69                154640       -6.60
# 3  2019             2831.55                165760        3.74
# 4  2018             2702.93                159840        6.45
# 5  2017             2651.47                158480        6.80

# %%
gdp=gdp[1:]

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 1 to 62
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  62 non-null     object
#  1   GDP in (Billion) $    62 non-null     object
#  2   Per Capita in rupees  62 non-null     object
#  3   Growth per            62 non-null     object
# dtypes: object(4)
# memory usage: 2.1+ KB

# %% [markdown]
# all the entries the data are object type so converted them into int and float data types

# %%
gdp['Year']=gdp['Year'].astype(int)

# %%
gdp[ 'Per Capita in rupees']=gdp['Per Capita in rupees'].astype(int)

# %%
gdp['GDP in (Billion) $']=gdp['GDP in (Billion) $'].astype(float)

# %%
gdp['Growth per']=gdp['Growth per'].astype(float)

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 1 to 62
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  62 non-null     int32
#  1   GDP in (Billion) $    62 non-null     float64
#  2   Per Capita in rupees  62 non-null     int32
#  3   Growth per            62 non-null     float64
# dtypes: float64(2), int32(2)
# memory usage: 1.6 KB

# %% [markdown]
# # corelation check
# 1. checke for the co-relation betwen the features and corelation with GDP
# 2. visualized the data as per the same

# %%
gdp.corr()
# Out:
#                           Year  GDP in (Billion) $  Per Capita in rupees  \
# Year                  1.000000            0.848482              0.867579
# GDP in (Billion) $    0.848482            1.000000              0.998554
# Per Capita in rupees  0.867579            0.998554              1.000000
# Growth per            0.307211            0.169999              0.189860
#
#                       Growth per
# Year                    0.307211
# GDP in (Billion) $      0.169999
# Per Capita in rupees    0.189860
# Growth per              1.000000

# %%
sns.heatmap(gdp.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
gdp.corr()['GDP in (Billion) $']
# Out:
# Year                    0.848482
# GDP in (Billion) $      1.000000
# Per Capita in rupees    0.998554
# Growth per              0.169999
# Name: GDP in (Billion) $, dtype: float64

# %% [markdown]
# # insight
# * gdp of the country is directly proportional with percapita income of people
# * and it is having very good corellation with year indicating that with increase in the percapita and GDP

# %%
sns.set_style('whitegrid')
plt.plot(gdp['Year'],gdp['GDP in (Billion) $'],color='red', linestyle='-',linewidth=2)
plt.xlabel('year')
plt.ylabel('GDP in bill')
plt.title('GDP RATE OVER YEARS')
# Out:
# Text(0.5, 1.0, 'GDP RATE OVER YEARS')

# %%
sns.set_style('whitegrid')
plt.plot(gdp['Year'],gdp['Per Capita in rupees'],color='red', linestyle='-',linewidth=2)
plt.xlabel('year')
plt.ylabel('Per Capita in rupees')
plt.title('PER CAPITA OVER YEARS')
# Out:
# Text(0.5, 1.0, 'PER CAPITA OVER YEARS')

# %% [markdown]
# # linear realtion
# 1. the corelation of gdp with per capita was very and same can be seen below

# %%
sns.set_style('whitegrid')
plt.plot(gdp['Per Capita in rupees'],gdp['GDP in (Billion) $'],color='green', linestyle='-',linewidth=2)
plt.xlabel('Per Capita in rupees')
plt.ylabel('GDP in (Billion) $')
plt.title('PER CAPITA vs GDP')
# Out:
# Text(0.5, 1.0, 'PER CAPITA vs GDP')

# %% [markdown]
# # model training and evaluation

# %%
X=gdp[['Year','Per Capita in rupees']]

# %%
y=gdp['GDP in (Billion) $']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (43, 2)

# %%
y_train.shape
# Out:
# (43,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print('r2 score :',r2_score(y_test,y_pred))
print('\n')
print('MAE:',mean_absolute_error(y_test,y_pred))
print('\n')
print('MSE:',mean_squared_error(y_test,y_pred))
print('\n')
print('RSME:',mean_squared_error(y_test,y_pred,squared=False))
# Out:
# r2 score : 0.9987880786255451
#
#
# MAE: 24.237752210056936
#
#
# MSE: 1131.2996097939813
#
#
# RSME: 33.63479760298821

# %%
sns.lmplot(x='Per Capita in rupees',y='GDP in (Billion) $',data=gdp)
